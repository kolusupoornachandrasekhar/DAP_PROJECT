# %%
#load libraries
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz,plot_tree
from IPython.display import Image

# %%
df=pd.read_csv("/content/drive/MyDrive/dataset/adult_income/income_train.csv")
print(df)
# Out:
#     Unnamed: 0  age  education.num  sex  hours.per.week  income
# 0            0   90              9    0              40       0
# 1            1   82              9    0              18       0
# 2            2   66             10    0              40       1
# 3            3   54              4    0              40       0
# 4            4   41             10    0              40       0
# 5            5   34              9    0              45       1
# 6            6   38              6    1              40       0
# 7            7   74             16    0              20       1
# 8            8   68              9    0              40       0
# 9            9   41             10    1              60       1
# 10          10   45             16    0              35       1
# 11          11   38             15    1              45       0
# 12          12   52             13    0              20       1
# 13          13   32             14    1              55       1
# 14          14   51             16    1              40       1
# 15          15   46             15    1              40       1
# 16          16   45              7    1              76       0
# 17          17   57             14    1              50       1
# 18          18   22             12    1              40       1
# 19          19   34             13    1              50       1
# 20          20   37             13    1              40       1
# 21          21   29              7    0              42       0
# 22          22   61              9    0              25       0
# 23          23   51             10    1              40       1
# 24          24   61              9    1              32       0
# 25          25   21             11    1              40       0
# 26          26   33              2    1              32       1
# 27          27   49              3    1              40       0
# 28          28   37              6    1              50       1
# 29          29   38              6    1              90       1
# 30          30   23             10    1              40       1
# 31          31   59              6    0              50       0
# 32          32   52             15    1              60       1
# 33          33   51             13    1              50       1
# 34          34   60              9    1              50       0
# 35          35   63             16    0              60       1
# 36          36   53              9    1              48       0
# 37          37   51             15    0              50       1
# 38          38   37             16    0              60       1
# 39          39   54             14    0              40       0
# 40          40   44             13    1              50       1
# 41          41   43             14    0              40       1
# 42          42   51             10    0              40       1
# 43          43   43             14    0              40       1
# 44          44   71              9    1              15       0
# 45          45   48             13    0              70       1
# 46          46   71              9    1              52       0
# 47          47   73              9    1              40       0
# 48          48   68             10    0              40       0
# 49          49   67             10    1              40       0
# 50          50   40             15    1              45       1
# 51          51   50              9    0              72       1

# %%
feature_cols=['age','education.num','hours.per.week']
feature=df[feature_cols] #features
Target=df.income #target variable

# %%
#create decision tree classifer object
DT=DecisionTreeClassifier()
#train decision tree classifier
DT=DT.fit(feature,Target)

# %%
#predict the response for test dataset
age=int(input("Enter age:"))
education_no=int(input("Enter education num:"))
hours_per_week=int(input("Enter hours_per_week:"))
pred=DT.predict([[age,education_no,hours_per_week]])
if pred==1:
  print("greater than 50,0000")
else:
  print("less than 50,000")
# Out:
# Enter age:50
# Enter education num:9
# Enter hours_per_week:72
# greater than 50,0000
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plot_tree(DT) #plot_tree(trained model name)
# Out:
# [Text(0.6, 0.9375, 'x[1] <= 11.5\ngini = 0.488\nsamples = 52\nvalue = [22, 30]'),
#  Text(0.35, 0.8125, 'x[0] <= 52.0\ngini = 0.444\nsamples = 30\nvalue = [20, 10]'),
#  Text(0.25, 0.6875, 'x[0] <= 49.5\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.2, 0.5625, 'x[2] <= 43.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.1, 0.4375, 'x[2] <= 36.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.05, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15, 0.3125, 'x[0] <= 26.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.1, 0.1875, 'x[1] <= 10.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2, 0.1875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3, 0.4375, 'x[0] <= 43.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.25, 0.3125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.35, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3, 0.5625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.45, 0.6875, 'x[1] <= 9.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.4, 0.5625, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.5, 0.5625, 'x[0] <= 66.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.45, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.55, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.85, 0.8125, 'x[2] <= 47.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.8, 0.6875, 'x[2] <= 42.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.7, 0.5625, 'x[0] <= 53.0\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.65, 0.4375, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.75, 0.4375, 'x[2] <= 30.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9, 0.5625, 'x[0] <= 39.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.85, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.95, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.6875, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]')]

# %%
#RANDOMFOREST

# %%
#load libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv("/content/drive/MyDrive/dataset/adult_income/income_train.csv")
print(df)
# Out:
#     Unnamed: 0  age  fnlwgt  education.num  sex  capital.gain  capital.loss  \
# 0            0   90   77053              9    0             0          4356
# 1            1   82  132870              9    0             0          4356
# 2            2   66  186061             10    0             0          4356
# 3            3   54  140359              4    0             0          3900
# 4            4   41  264663             10    0             0          3900
# 5            5   34  216864              9    0             0          3770
# 6            6   38  150601              6    1             0          3770
# 7            7   74   88638             16    0             0          3683
# 8            8   68  422013              9    0             0          3683
# 9            9   41   70037             10    1             0          3004
# 10          10   45  172274             16    0             0          3004
# 11          11   38  164526             15    1             0          2824
# 12          12   52  129177             13    0             0          2824
# 13          13   32  136204             14    1             0          2824
# 14          14   51  172175             16    1             0          2824
# 15          15   46   45363             15    1             0          2824
# 16          16   45  172822              7    1             0          2824
# 17          17   57  317847             14    1             0          2824
# 18          18   22  119592             12    1             0          2824
# 19          19   34  203034             13    1             0          2824
# 20          20   37  188774             13    1             0          2824
# 21          21   29   77009              7    0             0          2754
# 22          22   61   29059              9    0             0          2754
# 23          23   51  153870             10    1             0          2603
# 24          24   61  135285              9    1             0          2603
# 25          25   21   34310             11    1             0          2603
# 26          26   33  228696              2    1             0          2603
# 27          27   49  122066              3    1             0          2603
# 28          28   37  107164              6    1             0          2559
# 29          29   38  175360              6    1             0          2559
# 30          30   23   44064             10    1             0          2559
# 31          31   59  107287              6    0             0          2559
# 32          32   52  198863             15    1             0          2559
# 33          33   51  123011             13    1             0          2559
# 34          34   60  205246              9    1             0          2559
# 35          35   63   39181             16    0             0          2559
# 36          36   53  149650              9    1             0          2559
# 37          37   51  197163             15    0             0          2559
# 38          38   37  137527             16    0             0          2559
# 39          39   54  161691             14    0             0          2559
# 40          40   44  326232             13    1             0          2547
# 41          41   43  115806             14    0             0          2547
# 42          42   51  115066             10    0             0          2547
# 43          43   43  289669             14    0             0          2547
# 44          44   71  100820              9    1             0          2489
# 45          45   48  121253             13    0             0          2472
# 46          46   71  110380              9    1             0          2467
# 47          47   73  233882              9    1             0          2457
# 48          48   68  192052             10    0             0          2457
# 49          49   67  174995             10    1             0          2457
# 50          50   40  335549             15    1             0          2444
# 51          51   50  237729              9    0             0          2444
#
#     hours.per.week  income
# 0               40       0
# 1               18       0
# 2               40       1
# 3               40       0
# 4               40       0
# 5               45       1
# 6               40       0
# 7               20       1
# 8               40       0
# 9               60       1
# 10              35       1
# 11              45       0
# 12              20       1
# 13              55       1
# 14              40       1
# 15              40       1
# 16              76       0
# 17              50       1
# 18              40       1
# 19              50       1
# 20              40       1
# 21              42       0
# 22              25       0
# 23              40       1
# 24              32       0
# 25              40       0
# 26              32       1
# 27              40       0
# 28              50       1
# 29              90       1
# 30              40       1
# 31              50       0
# 32              60       1
# 33              50       1
# 34              50       0
# 35              60       1
# 36              48       0
# 37              50       1
# 38              60       1
# 39              40       0
# 40              50       1
# 41              40       1
# 42              40       1
# 43              40       1
# 44              15       0
# 45              70       1
# 46              52       0
# 47              40       0
# 48              40       0
# 49              40       0
# 50              45       1
# 51              72       1

# %%
feature_cols=['age','education.num','hours.per.week']
feature=df[feature_cols] #features
Target=df.income #target variable

# %%
RF=RandomForestClassifier(n_estimators=10)
RF.fit(feature,Target)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
#predict the response for test dataset
age=int(input("Enter age:"))
education_no=int(input("Enter education num:"))
hours_per_week=int(input("Enter hours_per_week:"))
pred=DT.predict([[age,education_no,hours_per_week]])
if pred==1:
  print("greater than 50,0000")
else:
  print("less than 50,000")
# Out:
# Enter age:32
# Enter education num:14
# Enter hours_per_week:55
# greater than 50,0000
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt
a=pd.read_csv("/content/drive/MyDrive/dataset/adult_income/income_train.csv")
sns.barplot(x="age",y="hours.per.week",data=a)

plt.title("Income of an adult")
plt.xlabel("age")
plt.ylabel("hours.per.week")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
a=pd.read_csv("/content/drive/MyDrive/dataset/adult_income/income_train.csv")
sns.lineplot(x="age",y="hours.per.week",data=a)

plt.title("Income of an adult")
plt.xlabel("age")
plt.ylabel("hours.per.week")
plt.show()
